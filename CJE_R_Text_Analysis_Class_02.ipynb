# %% [markdown]
# # English Text Data Analysis

# %% [markdown]
# * using avengers script data
# * data import and wrangling
# * tokenizing
# * stop_words handling using stop_words
# * sentiment analysis using sentiments
# * visualization and others

# %% [markdown]
# ## library load

# %% [markdown]
# * 아래와 같은 패키지들을 load합니다.
# * 모든 패키지가 다 사용되지 않을 수도 있습니다.
# * 패키지가 설치되어야 로드될 수 있습니다.
# * 패키지 설치는 아래의 명령어로 설치합니다.
# > install.packages("패키지이름")

# %%
# dplyr grammar
library(tidyverse)
library(reshape2)
library(readtext)

# text analysis
library(stringr)
library(tidytext)
library(sentimentr)

# visualizationo
library(ggplot2)
library(wordcloud)
library(gridExtra)
library(ggthemes)

# network analysis
library(tidygraph)
library(ggraph)
# Out:
# ─ Attaching packages ──────────────────── tidyverse 1.2.1 ─
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.3       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ─ Conflicts ───────────────────── tidyverse_conflicts() ─
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘reshape2’
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
# Loading required package: RColorBrewer
#
# Attaching package: ‘gridExtra’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# Attaching package: ‘tidygraph’
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %% [markdown]
# ## importing data

# %% [markdown]
# * 분석을 하려는 데이터를 가져옵니다.
# * 데이터는 github에 올려두었습니다.
# * 분석에 사용할 데이터는 2개입니다.
# * 영화 avengers의 영문 시나리오 데이터입니다.
#     * avengers 2: https://raw.githubusercontent.com/af2020/pnu/master/data/age_of_ultron_script_tab_sep.txt
#     * avengers 3: https://raw.githubusercontent.com/af2020/pnu/master/data/infinity_war_script_tab_sep.txt

# %% [markdown]
# * 데이터를 가져오기 전에 먼저 텍스트 데이터를 열어서 확인해봅니다.
# > * hero : 시나리오 상에서 대사를 하는 주인공 이름
# > * script: 해당 주인공의 대사
# * 이렇게 2개의 컬럼으로 구성되어 있고, 탭으로 구분되어 있습니다.
#
# * tidytext 패키지를 이용하기 위해서는 데이터가 tibble 형식이어야 합니다.
# * 데이터를 가져올 때, tibble 형식으로 가져오기 위해 read_delim() 함수를 이용합니다.
# * read_delim() 함수는 사용자가 구분자를 지정할 수 있습니다.

# %% [markdown]
# * 데이터가 저장되어 있는 주소를 변수로 지정합니다.

# %%
# avengers 2 data url
a2_url <- 'https://raw.githubusercontent.com/af2020/pnu/master/data/age_of_ultron_script_tab_sep.txt'
# avengers 2 data url
a3_url <- 'https://raw.githubusercontent.com/af2020/pnu/master/data/infinity_war_script_tab_sep.txt'
a4_url <- 'https://raw.githubusercontent.com/af2020/pnu/master/data/eng_game_script_tab_sep.txt'

# %% [markdown]
# * 데이터를 가져옵니다.

# %%
read_delim(a2_url, delim='\t')
# Out:
# Parsed with column specification:
# cols(
#   hero = col_character(),
#   script = col_character()
# )
#      hero
# 1    Announcer
# 2    **
# 3    Tony Stark
# 4    Steve Rogers
# 5    JARVIS
# 6    Thor
# 7    **
# 8    Natasha Romanoff
# 9    **
# 10   Clint Barton
# 11   Tony Stark
# 12   Steve Rogers
# 13   **
# 14   Steve Rogers
# 15   **
# 16   Strucker
# 17   Fortress Soldier
# 18   Strucker
# 19   Fortress Soldier
# 20   Strucker
# 21   Fortress Soldier
# 22   Strucker
# 23   Dr. List
# 24   Strucker
# 25   Dr. List
# 26   Strucker
# 27   **
# 28   Jarvis
# 29   Tony Stark
# 30   Iron Legion
# ⋮    ⋮
# 1001 Steve Rogers
# 1002 Tony Stark
# 1003 Steve Rogers
# 1004 Thor
# 1005 Steve Rogers
# 1006 Tony Stark
# 1007 Steve Rogers
# 1008 Thor
# 1009 Tony Stark
# 1010 Thor
# 1011 Tony Stark
# 1012 Steve Rogers
# 1013 Thor
# 1014 Tony Stark
# 1015 Steve Rogers
# 1016 Tony Stark
# 1017 Steve Rogers
# 1018 Tony Stark
# 1019 Steve Rogers
# 1020 Tony Stark
# 1021 Steve Rogers
# 1022 Natasha Romanoff
# 1023 Steve Rogers
# 1024 Natasha Romanoff
# 1025 Steve Rogers
# 1026 Natasha Romanoff
# 1027 Steve Rogers
# 1028 **
# 1029 Thanos
# 1030 **
#      script
# 1     [first lines; announcement over speaker] Report to your stations immediately. This is not a drill. We are under attack. We are under attack.
# 2     [the Avengers are in the process of infiltrating a HYDRA base in Sokovia, and Iron Man bounces off of the base's force field]
# 3     Shit!
# 4     Language! JARVIS, what's the view from upstairs?
# 5     The central building is protected by some kind of energy shield. Strucker's technology is well beyond any other Hydra base we've taken.
# 6     Loki's scepter must be here. Strucker couldn't mount this defense without it. At long last.
# 7     [Natasha knocks out some soldiers]
# 8     At long last is lasting a little long, boys.
# 9     [As some soldiers shoot at him]
# 10    Yeah. I think we lost the element of surprise.
# 11    Wait a second. No one else is going to deal with the fact that Cap just said "language?"
# 12    I know.
# 13    [Steve throws his bike at some soldiers driving up in their truck]
# 14    It just slipped out.
# 15    [at the HYDRA Research Base, Sokovia, Eastern Europe]
# 16    Who gave the order to attack?
# 17    Herr Strucker, it's the Avengers. They landed in the far woods, the perimeter guard panicked.
# 18    [to List] They have to be after the scepter. [to the soldier] Can we hold them?
# 19    They are the Avengers!
# 20    Deploy the rest of the tanks.
# 21    Yes, sir.
# 22    Concentrate fire on the weak ones. A hit can make them close ranks. Everything we've accomplished. But we're on the verge of our greatest breakthrough.
# 23    Then let's show them what we've accomplished. Send out the twins.
# 24    It's too soon.
# 25    It's what they signed up for.
# 26    My men can hold them.
# 27    [Stark flies to the HYDRA base to break in]
# 28    Sir, the city is taking fire.
# 29    Well, we know Strucker's not going to worry about civilian casualties. Send in the Iron Legion.
# 30    [The Iron Legion flies in; to the civilians] This quadrant is unsafe. Please back away. We are here to help. This quadrant is unsafe. Please back away. Please back away. We wish to avoid collateral damage and will inform you when this current conflict is resolved. We are here to help.
# ⋮    ⋮
# 1001  Right. Different rules for us.
# 1002  Nice guy, but artificial.
# 1003  Thank you.
# 1004  If he can wield the hammer, he can keep the Mind Stone. It's safe with the Vision and these days, safe is in short supply.
# 1005  But if you put the hammer in an elevator...
# 1006  It would still go up.
# 1007  Elevator's not worthy.
# 1008  I'm going to miss these little talks of ours.
# 1009  Well, not if you don't leave.
# 1010  I have no choice. The Mind Stone is the fourth of the Infinity Stones to show up in the last few years. That's not a coincidence. Someone has been playing an intricate game and has made pawns of us. But once all these pieces are in position...
# 1011  Triple Yahtzee?
# 1012  You think you can find out what's coming?
# 1013  I do. Besides this one, there's nothing that can't be explained. [Thor returns to Asgard which burns a circle in the grass he was standing on]
# 1014  That man has no regard for lawn maintenance. I'm gonna miss him though. And you're gonna miss me. There's gonna be a lot of manful tears. [as they walk over towards Stark's car]
# 1015  I will miss you, Tony.
# 1016  Yeah? Well, it's time for me to tap out. Maybe I should take a page out of Barton's book and build Pepper a farm, hope nobody blows it up.
# 1017  The simple life.
# 1018  You'll get there one day.
# 1019  I don't know, family, stability. The guy who wanted all that went in the ice seventy-five years ago. I think someone else came out. [Stark turns to get into his car]
# 1020  You alright?
# 1021  I'm home. [last lines; Steve finds Natasha standing alone] You want to keep staring at the wall, or do you want to go to work? I mean, it's a pretty interesting wall.
# 1022  I thought you and Tony were still gazing into each other's eyes. How do we look?
# 1023  Well, we're not the '27 Yankees. [hands Natasha a tablet]
# 1024  We've got some hitters.
# 1025  They're good. They're not a team.
# 1026  Let's beat 'em into shape. [they gather Rhodes in his War Machine suit, Sam in his Falcon suit, Wanda in a new suit, and Vision]
# 1027  Avengers...!
# 1028  [mid-credits scene; we see the Infinity Gauntlet without any of the Stones, dissatisfied Thanos opens a vault and puts on The Infinty Gauntlet, revealing himself]
# 1029  Fine, I'll do it myself.
# 1030  [End of Avengers - Age of Ultron]

# %% [markdown]
# * 가져오려는 데이터의 각 컬럼의 type을 지정해주는 것이 좋습니다.
# * 아래와 같이 가져올 수 있습니다.

# %%
a2 <- read_delim(a2_url, delim='\t', col_types=list(hero = col_character(), script = col_character()))
a3 <- read_delim(a3_url, delim='\t', col_types=list(hero = col_character(), script = col_character()))
a4 <- read_delim(a4_url, delim='\t', col_types=list(hero = col_character(), script = col_character()))
# Out:
# Error in read_delim(a2_url, delim = "\t", col_types = list(hero = col_character(), : 함수 "read_delim"를 찾을 수 없습니다
# Traceback:

# %% [markdown]
# * 데이터가 정상적으로 read 되었는지 살펴보겠습니다.

# %%
a2  %>% head(5)
# Out:
#   hero
# 1 Announcer
# 2 **
# 3 Tony Stark
# 4 Steve Rogers
# 5 JARVIS
#   script
# 1  [first lines; announcement over speaker] Report to your stations immediately. This is not a drill. We are under attack. We are under attack.
# 2  [the Avengers are in the process of infiltrating a HYDRA base in Sokovia, and Iron Man bounces off of the base's force field]
# 3  Shit!
# 4  Language! JARVIS, what's the view from upstairs?
# 5  The central building is protected by some kind of energy shield. Strucker's technology is well beyond any other Hydra base we've taken.

# %% [markdown]
# ## wrangling data

# %% [markdown]
# * avengers 2,3 데이터를 각각 a2, a3의 이름으로 read 했습니다.
# * 분석을 위해서 데이터 처리를 해야 할 것이 있습니다.
#     1. a2와 a3는 컬럼 구조가 같으므로 분석의 편의를 위해 하나의 데이터로 통합하려고 합니다.
#     2. 현재 데이터에는 대화와 지문이 섞여 있습니다. 지문을 제외하고 대화만 추출하여 분석하려고 합니다.

# %% [markdown]
# ### bind_rows()

# %% [markdown]
# * bind_rows() 함수를 이용하면 2개의 data frame을 행으로 합칠 수 있습니다.
# * 다만, a2인지, a3인지를 구분해주는 dummy 컬럼이 있어야 합니다.

# %%
# dummy column add using mutate
a2 %>% mutate(movie = 2) -> a2
a3 %>% mutate(movie = 3) -> a3
# Out:
#      hero
# 1    Announcer
# 2    **
# 3    Tony Stark
# 4    Steve Rogers
# 5    JARVIS
# 6    Thor
# 7    **
# 8    Natasha Romanoff
# 9    **
# 10   Clint Barton
# 11   Tony Stark
# 12   Steve Rogers
# 13   **
# 14   Steve Rogers
# 15   **
# 16   Strucker
# 17   Fortress Soldier
# 18   Strucker
# 19   Fortress Soldier
# 20   Strucker
# 21   Fortress Soldier
# 22   Strucker
# 23   Dr. List
# 24   Strucker
# 25   Dr. List
# 26   Strucker
# 27   **
# 28   Jarvis
# 29   Tony Stark
# 30   Iron Legion
# ⋮    ⋮
# 1001 Steve Rogers
# 1002 Tony Stark
# 1003 Steve Rogers
# 1004 Thor
# 1005 Steve Rogers
# 1006 Tony Stark
# 1007 Steve Rogers
# 1008 Thor
# 1009 Tony Stark
# 1010 Thor
# 1011 Tony Stark
# 1012 Steve Rogers
# 1013 Thor
# 1014 Tony Stark
# 1015 Steve Rogers
# 1016 Tony Stark
# 1017 Steve Rogers
# 1018 Tony Stark
# 1019 Steve Rogers
# 1020 Tony Stark
# 1021 Steve Rogers
# 1022 Natasha Romanoff
# 1023 Steve Rogers
# 1024 Natasha Romanoff
# 1025 Steve Rogers
# 1026 Natasha Romanoff
# 1027 Steve Rogers
# 1028 **
# 1029 Thanos
# 1030 **
#      script
# 1     [first lines; announcement over speaker] Report to your stations immediately. This is not a drill. We are under attack. We are under attack.
# 2     [the Avengers are in the process of infiltrating a HYDRA base in Sokovia, and Iron Man bounces off of the base's force field]
# 3     Shit!
# 4     Language! JARVIS, what's the view from upstairs?
# 5     The central building is protected by some kind of energy shield. Strucker's technology is well beyond any other Hydra base we've taken.
# 6     Loki's scepter must be here. Strucker couldn't mount this defense without it. At long last.
# 7     [Natasha knocks out some soldiers]
# 8     At long last is lasting a little long, boys.
# 9     [As some soldiers shoot at him]
# 10    Yeah. I think we lost the element of surprise.
# 11    Wait a second. No one else is going to deal with the fact that Cap just said "language?"
# 12    I know.
# 13    [Steve throws his bike at some soldiers driving up in their truck]
# 14    It just slipped out.
# 15    [at the HYDRA Research Base, Sokovia, Eastern Europe]
# 16    Who gave the order to attack?
# 17    Herr Strucker, it's the Avengers. They landed in the far woods, the perimeter guard panicked.
# 18    [to List] They have to be after the scepter. [to the soldier] Can we hold them?
# 19    They are the Avengers!
# 20    Deploy the rest of the tanks.
# 21    Yes, sir.
# 22    Concentrate fire on the weak ones. A hit can make them close ranks. Everything we've accomplished. But we're on the verge of our greatest breakthrough.
# 23    Then let's show them what we've accomplished. Send out the twins.
# 24    It's too soon.
# 25    It's what they signed up for.
# 26    My men can hold them.
# 27    [Stark flies to the HYDRA base to break in]
# 28    Sir, the city is taking fire.
# 29    Well, we know Strucker's not going to worry about civilian casualties. Send in the Iron Legion.
# 30    [The Iron Legion flies in; to the civilians] This quadrant is unsafe. Please back away. We are here to help. This quadrant is unsafe. Please back away. Please back away. We wish to avoid collateral damage and will inform you when this current conflict is resolved. We are here to help.
# ⋮    ⋮
# 1001  Right. Different rules for us.
# 1002  Nice guy, but artificial.
# 1003  Thank you.
# 1004  If he can wield the hammer, he can keep the Mind Stone. It's safe with the Vision and these days, safe is in short supply.
# 1005  But if you put the hammer in an elevator...
# 1006  It would still go up.
# 1007  Elevator's not worthy.
# 1008  I'm going to miss these little talks of ours.
# 1009  Well, not if you don't leave.
# 1010  I have no choice. The Mind Stone is the fourth of the Infinity Stones to show up in the last few years. That's not a coincidence. Someone has been playing an intricate game and has made pawns of us. But once all these pieces are in position...
# 1011  Triple Yahtzee?
# 1012  You think you can find out what's coming?
# 1013  I do. Besides this one, there's nothing that can't be explained. [Thor returns to Asgard which burns a circle in the grass he was standing on]
# 1014  That man has no regard for lawn maintenance. I'm gonna miss him though. And you're gonna miss me. There's gonna be a lot of manful tears. [as they walk over towards Stark's car]
# 1015  I will miss you, Tony.
# 1016  Yeah? Well, it's time for me to tap out. Maybe I should take a page out of Barton's book and build Pepper a farm, hope nobody blows it up.
# 1017  The simple life.
# 1018  You'll get there one day.
# 1019  I don't know, family, stability. The guy who wanted all that went in the ice seventy-five years ago. I think someone else came out. [Stark turns to get into his car]
# 1020  You alright?
# 1021  I'm home. [last lines; Steve finds Natasha standing alone] You want to keep staring at the wall, or do you want to go to work? I mean, it's a pretty interesting wall.
# 1022  I thought you and Tony were still gazing into each other's eyes. How do we look?
# 1023  Well, we're not the '27 Yankees. [hands Natasha a tablet]
# 1024  We've got some hitters.
# 1025  They're good. They're not a team.
# 1026  Let's beat 'em into shape. [they gather Rhodes in his War Machine suit, Sam in his Falcon suit, Wanda in a new suit, and Vision]
# 1027  Avengers...!
# 1028  [mid-credits scene; we see the Infinity Gauntlet without any of the Stones, dissatisfied Thanos opens a vault and puts on The Infinty Gauntlet, revealing himself]
# 1029  Fine, I'll do it myself.
# 1030  [End of Avengers - Age of Ultron]
#      movie
# 1    2
# 2    2
# 3    2
# 4    2
# 5    2
# 6    2
# 7    2
# 8    2
# 9    2
# 10   2
# 11   2
# 12   2
# 13   2
# 14   2
# 15   2
# 16   2
# 17   2
# 18   2
# 19   2
# 20   2
# 21   2
# 22   2
# 23   2
# 24   2
# 25   2
# 26   2
# 27   2
# 28   2
# 29   2
# 30   2
# ⋮    ⋮
# 1001 2
# 1002 2
# 1003 2
# 1004 2
# 1005 2
# 1006 2
# 1007 2
# 1008 2
# 1009 2
# 1010 2
# 1011 2
# 1012 2
# 1013 2
# 1014 2
# 1015 2
# 1016 2
# 1017 2
# 1018 2
# 1019 2
# 1020 2
# 1021 2
# 1022 2
# 1023 2
# 1024 2
# 1025 2
# 1026 2
# 1027 2
# 1028 2
# 1029 2
# 1030 2

# %% [markdown]
# * bind_rows() 이용해서 merge 합니다.

# %%
bind_rows(a2, a3) -> a
# a2  %>% bind_rows(a3) -> a

a %>% tail(5)
# Out:
#   hero
# 1 **
# 2 **Nick Fury
# 3 **
# 4 ------
# 5 **
#   script
# 1 [*Fury then races back to their car and gets a what appears to be an old pager with extra gear attached out of his bag on the back seat. He sends out an emergency alert, mere seconds before his hand turns into ashes]*
# 2  Oh, no. Motherf-
# 3 [*Fury corrodes to dust. The pager falls to the ground, red lights blinking on the additions; the camera zooms in and we see the device display SENDING... then display a red-blue-and-gold star insignia -- the symbol of Captain Marvel.]*
# 4 NA
# 5 [*Screen title: Thanos will return]*
#   movie
# 1 3
# 2 3
# 3 3
# 4 3
# 5 3

# %% [markdown]
# * 제대로 합쳐졌는지 확인해보겠습니다.

# %%
a  %>% tail(5)

# a %>% str()
# Out:
#   hero
# 1 **
# 2 **Nick Fury
# 3 **
# 4 ------
# 5 **
#   script
# 1 [*Fury then races back to their car and gets a what appears to be an old pager with extra gear attached out of his bag on the back seat. He sends out an emergency alert, mere seconds before his hand turns into ashes]*
# 2  Oh, no. Motherf-
# 3 [*Fury corrodes to dust. The pager falls to the ground, red lights blinking on the additions; the camera zooms in and we see the device display SENDING... then display a red-blue-and-gold star insignia -- the symbol of Captain Marvel.]*
# 4 NA
# 5 [*Screen title: Thanos will return]*
#   movie
# 1 3
# 2 3
# 3 3
# 4 3
# 5 3

# %% [markdown]
# ###  Extracting Dialogue

# %% [markdown]
# * 현재까지 구성한 데이터에서 분석을 하기 위해서는 추가적으로 데이터를 처리해야합니다.
#     > * script 컬럼에 dialogue와 action이 섞여 있습니다. dialogue만 추출하여 분석하려고 합니다.
#     > * regular expression (정규식)을 사용하여 문자 처리를 하려고 합니다.
#     > * 원래 텍스트에 포함되어 있던 "*" 표시를 제외하려고 합니다.
#     > * 또한 script 중간에 [  ] 표시로 적혀 있는 action script도 제외하려고 합니다.
#     > * 각각의 script에 일련번호를 부여하려고 합니다.

# %%
# without *
(
    a
    # hero preprocess
    %>% mutate(hero2 = str_replace_all(hero,"\\**", ""))
    %>% mutate(hero3 = str_replace_all(hero2, "F.R.I.D.A.Y.", "F.R.I.D.A.Y"))
    %>% mutate(hero4 = str_replace_all(hero3, "F.R.I.D.A.Y", "FRIDAY"))
    %>% mutate(hero5 = str_replace_all(hero4, "Thor'", "Thor"))
    %>% mutate(hero6 = str_trim(hero5))
    
#     # script preprocess
    %>% mutate(script2 = str_replace_all(script,"\\*\\*\\*", ""))
    %>% mutate(script3 = str_replace_all(script2,"\\*\\*", ""))
    %>% mutate(script4 = str_replace_all(script3,"\\*", ""))
    
#     # dialouge extract
    %>% mutate(script_wop = str_replace_all(script4,"\\[[a-zA-Z0-9 . , : ; ' - é ? � ( ) / ! % -]+\\]",""))
    
#     # add index
    %>% mutate(id = row_number())
    
#     # select columns
    %>% select(id, movie, hero = hero6, script = script4, dlg = script_wop)
#     %>% head(5)
)  -> a

# %% [markdown]
# * 처리가 잘 되었는지 확인해보겠습니다.
# * 대화를 추출한 dlg 컬럼에 지문을 표시하는 [ 혹은 ] 표시가 포함되어 있는지 여부를 확인합니다. 1

# %%
a %>% filter(str_detect(dlg, "\\]")) %>% summarise(n())
# Out:
#   n()
# 1 1

# %%
(
    a
     %>% filter(str_detect(dlg, "\\]")) 
#      %>% summarise(n())
)
# Out:
#   id   movie hero
# 1 1780 3     Rocket
#   script
# 1  [to himself] Okay, time to be the captain. [walks to a console near by Thor], presses two buttons] So, dead brother, huh? Yeah, that can be annoying.
#   dlg
# 1   Okay, time to be the captain. , presses two buttons] So, dead brother, huh? Yeah, that can be annoying.

# %% [markdown]
# * 아래와 같이 괄호를 사용하면 코멘트처리를 하면서 분석 결과를 쉽게 재확인할 수 있습니다.
# * summarise()만 제외하면 해당 데이터를 아래와 같이 직접확인할 수 있습니다.

# %%
(
    a
    %>% filter(str_detect(dlg, "\\]"))
#     %>% summarise(n())
)
# Out:
#      id movie hero script dlg

# %% [markdown]
# * 해당 텍스트를 찾아서 수동으로 변경해보겠습니다.
# * str_replace() 함수를 이용했습니다.

# %%
(
    a
     %>% mutate(dlg2 = str_replace(dlg, ' , presses two buttons]',''))
) -> a

# %% [markdown]
# * 그리고, 새롭게 데이터를 구성합니다.

# %%
a  %>% select(id, movie, hero, script, dlg = dlg2) -> a

# %% [markdown]
# * 완성된 데이터를 살펴보겠습니다.

# %%
a  %>% head(5)
# Out:
#   id movie hero
# 1 1  2     Announcer
# 2 2  2
# 3 3  2     Tony Stark
# 4 4  2     Steve Rogers
# 5 5  2     JARVIS
#   script
# 1  [first lines; announcement over speaker] Report to your stations immediately. This is not a drill. We are under attack. We are under attack.
# 2  [the Avengers are in the process of infiltrating a HYDRA base in Sokovia, and Iron Man bounces off of the base's force field]
# 3  Shit!
# 4  Language! JARVIS, what's the view from upstairs?
# 5  The central building is protected by some kind of energy shield. Strucker's technology is well beyond any other Hydra base we've taken.
#   dlg
# 1   Report to your stations immediately. This is not a drill. We are under attack. We are under attack.
# 2
# 3  Shit!
# 4  Language! JARVIS, what's the view from upstairs?
# 5  The central building is protected by some kind of energy shield. Strucker's technology is well beyond any other Hydra base we've taken.

# %% [markdown]
# ## tokenizing

# %% [markdown]
# * 각 hero들의 대화(dlg) 컬럼의 텍스트를 분석하려고 합니다.
# * dlg 컬럼의 script를 단어 단위로 구분하여 데이터를 만들려고 합니다.
# * tidytext package의 tokenize를 사용합니다.

# %%
(
    a
    %>% select(id, movie, hero, dlg)
    %>% unnest_tokens(word, dlg)
    
)  -> a_dlg_word

# %%
a_dlg_word  %>% head(10)
# Out:
#    id movie hero      word
# 1  1  2     Announcer report
# 2  1  2     Announcer to
# 3  1  2     Announcer your
# 4  1  2     Announcer stations
# 5  1  2     Announcer immediately
# 6  1  2     Announcer this
# 7  1  2     Announcer is
# 8  1  2     Announcer not
# 9  1  2     Announcer a
# 10 1  2     Announcer drill

# %% [markdown]
# * 가장 많이 등장하는, 빈도수가 가장 높은 단어는 무엇일까요? avengers 1편과 2편을 합쳐서 통계를 내보겠습니다.

# %%
a_dlg_word %>% 
count(word, sort=TRUE)  %>% 
head(10)
# Out:
#    word n
# 1  the  731
# 2  you  678
# 3  i    557
# 4  to   446
# 5  a    409
# 6  it   306
# 7  is   237
# 8  of   230
# 9  and  229
# 10 we   220

# %% [markdown]
# * 대부분이 의미없는 단어들입니다.
# * stop words를 통해서 이런 단어들을 걸러내야 할 필요성이 있습니다.

# %% [markdown]
# ## handling stop words

# %% [markdown]
# * tokenize 된 word 중에는 의미없는 단어들이 포함되어 있습니다.
# * 분석에 방해가 되는 정보이므로 제거하려고 합니다.
# * 영문 stop words를 사용하면 이 작업을 수월하게 할 수 있습니다.
# * tidytext 패키지에서 제공하는 stop_words 사전을 살펴보겠습니다.

# %% [markdown]
# # word를 기준으로 group by 해서,
# # 각 단어가 3개 사전 모두에 속하는지 확인

# %%
stop_words  %>% 
filter(word == "would")
# Out:
#   word  lexicon
# 1 would SMART
# 2 would SMART
# 3 would snowball
# 4 would onix

# %%
stop_words  %>% 
group_by(word)  %>% 

summarise(CNT = n())  %>% 
arrange(desc(CNT))  %>% 
head(5)
# Out:
#   word  CNT
# 1 down  4
# 2 would 4
# 3 a     3
# 4 about 3
# 5 above 3

# %%
stop_words  %>% 
group_by(lexicon) %>%
summarise(CNT = n())
# Out:
#   lexicon  CNT
# 1 SMART    571
# 2 onix     404
# 3 snowball 174

# %%
stop_words  %>% head(5)
# Out:
#   word  lexicon
# 1 a     SMART
# 2 a's   SMART
# 3 able  SMART
# 4 about SMART
# 5 above SMART

# %% [markdown]
# * 이제 stop_words에 있는 단어를 제외해보겠습니다.
# * stop_words를 제외한 후에 빈도를 다시 계산해보겠습니다.

# %%
(
    a_dlg_word
#      %>% anti_join(stop_words, by='word') 
     %>% anti_join(stop_words_custom, by='word') 
     %>% count(word, sort=TRUE)
     %>% head(10)
)
# Out:
#    word    n
# 1  time    63
# 2  stone   53
# 3  stark   45
# 4  thanos  44
# 5  ultron  37
# 6  life    29
# 7  uh      28
# 8  world   27
# 9  alright 26
# 10 guys    26

# %% [markdown]
# * stop_words에 추가하기

# %%
my_stop_words <- tibble(word = c('yeah', 'gonna', 'wanna', 'hey', 'gotta'), lexicon="custom")

# %%
my_stop_words
# Out:
#   word  lexicon
# 1 yeah  custom
# 2 gonna custom
# 3 wanna custom
# 4 hey   custom
# 5 gotta custom

# %%
stop_words %>% bind_rows(my_stop_words) -> stop_words_custom # %>% tail(10)#  -> stop_words_custome

# %%
stop_words_custom  %>% tail(10)
# Out:
#    word     lexicon
# 1  young    onix
# 2  younger  onix
# 3  youngest onix
# 4  your     onix
# 5  yours    onix
# 6  yeah     custom
# 7  gonna    custom
# 8  wanna    custom
# 9  hey      custom
# 10 gotta    custom

# %% [markdown]
# * stop_words에서 제외하기

# %%
stop_words_custom %>% filter(word != "yeah")  %>% tail(10)# -> stop_words_wo_yeah
# Out:
#    word     lexicon
# 1  you      onix
# 2  young    onix
# 3  younger  onix
# 4  youngest onix
# 5  your     onix
# 6  yours    onix
# 7  gonna    custom
# 8  wanna    custom
# 9  hey      custom
# 10 gotta    custom

# %% [markdown]
# ## creating hero list

# %% [markdown]
# * 대화를 분석해서 hero 별로 결과를 보고 싶습니다.
# * 이를 위해서 hero list가 있어야 합니다.
# * a 데이터에서 hero 를 추출해보겠습니다.

# %% [markdown]
# * 먼저 hero 컬럼이 비어 있지 않아야 합니다. 공백으로 값이 없는 경우도 있고, 공백인 경우도 있습니다.
# * 이렇게 행을 추출하고, hero 컬럼에서 고유값을 행갯수와 함께 뽑아보겠습니다.

# %%
(
    a
    %>% filter(str_length(hero)!= 0)
    %>% filter(hero != ' ')
    %>% group_by(hero)
    %>% summarise(cnt = n())
#     %>% summarise(distinct = n_distinct(hero))
    %>% arrange(desc(cnt))
#     %>% filter(cnt >= 15)
    
)  -> hero_list

# %% [markdown]
# ## analysis topic 01 - fining too much talker

# %% [markdown]
# * what is the definition of 'too much talker'?
# * my definition of too much talker : average number of word in a script is high
# * we can use sentence index and word frequency
# * but we should use original script

# %%
(
    
    a_dlg_word
    %>% group_by(id, movie, hero)
    %>% summarise(word_cnt = n())
    
)
# Out:
#      id   movie hero             word_cnt
# 1     1   2     Announcer        18
# 2     3   2     Tony Stark        1
# 3     4   2     Steve Rogers      7
# 4     5   2     JARVIS           22
# 5     6   2     Thor             15
# 6     8   2     Natasha Romanoff  9
# 7    10   2     Clint Barton      9
# 8    11   2     Tony Stark       18
# 9    12   2     Steve Rogers      2
# 10   14   2     Steve Rogers      4
# 11   16   2     Strucker          6
# 12   17   2     Fortress Soldier 15
# 13   18   2     Strucker         11
# 14   19   2     Fortress Soldier  4
# 15   20   2     Strucker          6
# 16   21   2     Fortress Soldier  2
# 17   22   2     Strucker         25
# 18   23   2     Dr. List         11
# 19   24   2     Strucker          3
# 20   25   2     Dr. List          6
# 21   26   2     Strucker          5
# 22   28   2     Jarvis            6
# 23   29   2     Tony Stark       16
# 24   30   2     Iron Legion      43
# 25   32   2     Iron Legion       5
# 26   34   2     Strucker         22
# 27   35   2     Soldiers          2
# 28   36   2     Strucker         26
# 29   37   2     Dr. List          2
# 30   38   2     Strucker          7
# ⋮    ⋮    ⋮     ⋮                ⋮
# 1942 2299 3     Groot             3
# 1943 2300 3     Rocket            7
# 1944 2302 3     James Rhodes      5
# 1945 2304 3     Mantis            3
# 1946 2305 3     Drax              1
# 1947 2306 3     Tony Stark        2
# 1948 2307 3     Peter Quill       2
# 1949 2308 3     Doctor Strange    6
# 1950 2309 3     Peter Parker      7
# 1951 2310 3     Tony Stark        3
# 1952 2311 3     Peter Parker     36
# 1953 2312 3     Nebula            3
# 1954 2314 3     James Rhodes      8
# 1955 2315 3     Steve Rogers      2
# 1956 2317 3     ------            1
# 1957 2318 3     Nick Fury         5
# 1958 2319 3     Maria Hill       13
# 1959 2320 3     Nick Fury         3
# 1960 2321 3     Maria Hill        4
# 1961 2322 3     Nick Fury         6
# 1962 2323 3     Maria Hill        3
# 1963 2324 3     Nick Fury         6
# 1964 2325 3     Maria Hill        1
# 1965 2326 3     Nick Fury         2
# 1966 2328 3     Maria Hill        4
# 1967 2330 3     Nick Fury         4
# 1968 2331 3     Maria Hill        1
# 1969 2333 3     Nick Fury         1
# 1970 2335 3     Nick Fury         3
# 1971 2337 3     ------            1

# %%
(
    
    a_dlg_word
    %>% group_by(id, movie, hero)
    %>% summarise(word_cnt = n())
    
    #############################################
    # condition for word cnt for each script
    %>% filter(word_cnt >= 15)
    #############################################
            
    %>% group_by(movie, hero)
    %>% summarise(id_cnt = n_distinct(id), word_sum=sum(word_cnt), word_avg = word_sum/id_cnt) 
    %>% arrange(desc(word_avg))
    
    # condition for script cnt for each hero
    %>% filter(id_cnt>=5)
    %>% filter(movie == 2)
    
    #############################################
#     visualization
    #############################################
    
#     %>% select(movie, hero, word_avg)
#     %>% head(30)
#     %>% ggplot()
#     + geom_bar(aes(x=reorder(hero,word_avg), y=word_avg), stat='identity')
#     + coord_flip()


)
# Out:
#    movie hero             id_cnt word_sum word_avg
# 1  2     Clint Barton     11      386     35.09091
# 2  2     Ultron           30      914     30.46667
# 3  2     Nick Fury         9      231     25.66667
# 4  2     Tony Stark       55     1394     25.34545
# 5  2     Thor             15      376     25.06667
# 6  2     Steve Rogers     20      500     25.00000
# 7  2     Natasha Romanoff 17      401     23.58824
# 8  2     Maria Hill        6      136     22.66667
# 9  2     Dr. Helen Cho     8      156     19.50000
# 10 2     Wanda Maximoff    5       97     19.40000
# 11 2     Bruce Banner     15      270     18.00000

# %% [markdown]
# * 결과에 대해서 이런 생각을 해볼 수 있습니다.
# * 평균에 근거했기 때문에 발생할 수 있는 문제는 없을까?
# * 예를 들면, 문장 갯수가 많지만, 대부분의 문장이 짧은 반응이었다면 실제 의미있는 문장이 길었다고 해도 평균은 짧아질것
# * hero 별 문장 길이의 분포를 분석하고 이를 근거로 계산해야 의미있는 것이 될 것
# * 원래 script에서 문장에 포함된 단어의 갯수가 적은 것은 제외하고 분석에 포함해야 한다는 것을 확인할 수 있습니다.

# %%
(
    a
    %>% inner_join(a_dlg_word %>% group_by(id) %>% summarise(word_cnt=n()))
    %>% filter(hero == "Peter Parker")
    %>% filter(word_cnt >= 15)
)
# Out:
# Joining, by = "id"
#   id   movie hero
# 1 1677 3     Peter Parker
# 2 1680 3     Peter Parker
# 3 1687 3     Peter Parker
# 4 1845 3     Peter Parker
# 5 2311 3     Peter Parker
#   script
# 1  But it was such a long way down and I just thought about you on the way...
# 2  ...And I kinda stuck to the side of the ship. And this suit is ridiculously intuitive, by the way. So if anything, it's kinda your fault that I'm here.
# 3  It's just- You can't be a friendly neighborhood Spider-Man when there's no neighborhood. [he waits for Iron Man's reaction] Okay. That didn't really make any sense, but you know what I'm trying to say.
# 4  Let me just say, if aliens wind up implanting eggs in my chest or something, and I end up eating you, I'm sorry.
# 5  [stumbling and terrified] I don't know what's- I don't know what's happening. I don't- [Parker falls into Stark's arms, clutching him tight and crying] Save me, save me! I don't wanna go, I don't wanna go, sir, please. Please, I don't wanna go. I don't wanna go... I'm sorry. [Parker disintegrates into ashes in Stark's arms]
#   dlg
# 1  But it was such a long way down and I just thought about you on the way...
# 2  ...And I kinda stuck to the side of the ship. And this suit is ridiculously intuitive, by the way. So if anything, it's kinda your fault that I'm here.
# 3  It's just- You can't be a friendly neighborhood Spider-Man when there's no neighborhood.  Okay. That didn't really make any sense, but you know what I'm trying to say.
# 4  Let me just say, if aliens wind up implanting eggs in my chest or something, and I end up eating you, I'm sorry.
# 5   I don't know what's- I don't know what's happening. I don't-  Save me, save me! I don't wanna go, I don't wanna go, sir, please. Please, I don't wanna go. I don't wanna go... I'm sorry.
#   word_cnt
# 1 17
# 2 29
# 3 29
# 4 23
# 5 36

# %% [markdown]
# * word_cnt의 분포를 살펴보겠습니다.

# %%
(
    a_dlg_word
    %>% group_by(id, movie, hero)
    %>% summarise(word_cnt = n())
#     %>% filter(word_cnt >10)
    %>% ggplot(aes(x=word_cnt))
#     + geom_histogram(binwidth=1) 
    + geom_histogram(aes(y=..density..), fill="white", color = "gray") 
    + geom_density(alpha=0.2, fill = "#FF6666", color="#FF6666" )
    
)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# * hero별로 분포가 다르지 않을까요?

# %%
(
    a_dlg_word
    %>% group_by(id, movie, hero)
    %>% summarise(word_cnt = n())
    %>% arrange(hero)
    %>% inner_join(hero_list %>% filter(cnt >= 30))
    %>% ggplot(aes(x=word_cnt)) 
#     + geom_histogram(binwidth=1) 
    + geom_histogram(aes(y=..density..), fill="white", color = "gray") 
    + geom_density(alpha=0.2, fill = "#FF6666", color="#FF6666" )
    + facet_wrap(~hero, ncol=4)
    
#     %>% head(5)
)
# Out:
# Joining, by = "hero"
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# * 분포를 고려해볼 때, 최소한 문장당 몇글자 이상인 경우로 분석 대상을 한정해야 할까요?

# %% [markdown]
# ## analysis topic 02 - word cloud

# %%
(
    a_dlg_word
    %>% anti_join(stop_words)
#     %>% inner_join(hero_list %>% arrange(desc(cnt)) %>% head(10))
    %>% group_by(movie, hero, word)
    %>% summarise(word_cnt=n_distinct(id))
    %>% arrange(desc(word_cnt))
    
#     %>% filter(hero == "Steve Rogers")
    %>% filter(movie == 2)
   
    %>% with(wordcloud(word, word_cnt, max.words=100))
#     %>% head(5)
)
# Out:
# Joining, by = "word"
# NULL
# plot without title

# %% [markdown]
# ## analyis topic 03 - dialogue network

# %% [markdown]
# * hero간 대화를 나타내는 네트워크를 구성합니다.

# %%
(
    a
    %>% left_join(a_dlg_word %>% group_by(id) %>% summarise(word_cnt = n()))
    %>% mutate(hero_lead_01= lead(hero))
    %>% mutate(hero_lead_02=lead(hero_lead_01))
    %>% filter(hero == hero_lead_02)
    %>% filter(hero != '' & hero_lead_01 != '' & hero_lead_02 !='')
    %>% select(hero_source = hero, hero_target = hero_lead_01, id, movie, word_cnt, dlg)
#     %>% select(hero_source = hero, hero_target, id, movie, word_cnt,dlg)
#     %>% filter(hero_source != '' & hero_target != '')
    
) -> a_g
# Out:
# Joining, by = "id"

# %%
(
    a_g
    %>% select(hero_source, hero_target, word_cnt)
#     %>% select(hero_source, hero_target)
    %>% as_tbl_graph(directed=FALSE)
    %>% activate(nodes)
    %>% mutate(neighbors = centrality_degree())
    %>% arrange(desc(neighbors))
    %>% as.tibble()
    %>% head(10)
)
# Out:
# Warning message:
# “`as.tibble()` is deprecated, use `as_tibble()` (but mind the new semantics).
# This warning is displayed once per session.”
#    name             neighbors
# 1  Tony Stark       287
# 2  Bruce Banner     126
# 3  Steve Rogers     122
# 4  Thor             101
# 5  Ultron            86
# 6  Natasha Romanoff  85
# 7  Wanda Maximoff    71
# 8  Thanos            70
# 9  Peter Quill       69
# 10 Clint Barton      55

# %% [markdown]
# * 그래프 데이터로 layout을 구합니다.

# %%
create_layout(
    a_g %>% 
    select(hero_source, hero_target, word_cnt) %>% 
    as_tbl_graph(directed=TRUE), layout="fr") -> layout

# %% [markdown]
# * 시각화를 수행합니다.

# %%
(
    ggraph(layout)
#     + geom_edge_density(aes(fill=word_cnt))
#     + geom_edge_link(aes(width=word_cnt), alpha = 0.2)
    + geom_edge_link(color="orange", alpha = 0.2)
#     + geom_edge_link(alpha = 0.2, width=2)
    + geom_node_point(color= 'orange', size=2)
    + geom_node_text(aes(label=name), color = "blue", size=2, repel=TRUE)
#     + scale_color_brewer(palette = "Set1")
    + theme_graph()
)
# Out:
# plot without title

# %% [markdown]
# ## analysis topic 04 - sentiment analysis

# %% [markdown]
# * tidytext package에서 제공하는 sentiment dictionary를 이용하려고 합니다.
# * 어떻게 구성되어 있는지 살펴봅시다.

# %%
sentiments  %>% filter(lexicon == "AFINN")
# Out:
#      word       sentiment lexicon score
# 1    abandon    NA        AFINN   -2
# 2    abandoned  NA        AFINN   -2
# 3    abandons   NA        AFINN   -2
# 4    abducted   NA        AFINN   -2
# 5    abduction  NA        AFINN   -2
# 6    abductions NA        AFINN   -2
# 7    abhor      NA        AFINN   -3
# 8    abhorred   NA        AFINN   -3
# 9    abhorrent  NA        AFINN   -3
# 10   abhors     NA        AFINN   -3
# 11   abilities  NA        AFINN    2
# 12   ability    NA        AFINN    2
# 13   aboard     NA        AFINN    1
# 14   absentee   NA        AFINN   -1
# 15   absentees  NA        AFINN   -1
# 16   absolve    NA        AFINN    2
# 17   absolved   NA        AFINN    2
# 18   absolves   NA        AFINN    2
# 19   absolving  NA        AFINN    2
# 20   absorbed   NA        AFINN    1
# 21   abuse      NA        AFINN   -3
# 22   abused     NA        AFINN   -3
# 23   abuses     NA        AFINN   -3
# 24   abusive    NA        AFINN   -3
# 25   accept     NA        AFINN    1
# 26   accepted   NA        AFINN    1
# 27   accepting  NA        AFINN    1
# 28   accepts    NA        AFINN    1
# 29   accident   NA        AFINN   -2
# 30   accidental NA        AFINN   -2
# ⋮    ⋮          ⋮         ⋮       ⋮
# 2447 worry      NA        AFINN   -3
# 2448 worrying   NA        AFINN   -3
# 2449 worse      NA        AFINN   -3
# 2450 worsen     NA        AFINN   -3
# 2451 worsened   NA        AFINN   -3
# 2452 worsening  NA        AFINN   -3
# 2453 worsens    NA        AFINN   -3
# 2454 worshiped  NA        AFINN    3
# 2455 worst      NA        AFINN   -3
# 2456 worth      NA        AFINN    2
# 2457 worthless  NA        AFINN   -2
# 2458 worthy     NA        AFINN    2
# 2459 wow        NA        AFINN    4
# 2460 wowow      NA        AFINN    4
# 2461 wowww      NA        AFINN    4
# 2462 wrathful   NA        AFINN   -3
# 2463 wreck      NA        AFINN   -2
# 2464 wrong      NA        AFINN   -2
# 2465 wronged    NA        AFINN   -2
# 2466 wtf        NA        AFINN   -4
# 2467 yeah       NA        AFINN    1
# 2468 yearning   NA        AFINN    1
# 2469 yeees      NA        AFINN    2
# 2470 yes        NA        AFINN    1
# 2471 youthful   NA        AFINN    2
# 2472 yucky      NA        AFINN   -2
# 2473 yummy      NA        AFINN    3
# 2474 zealot     NA        AFINN   -2
# 2475 zealots    NA        AFINN   -2
# 2476 zealous    NA        AFINN    2

# %%
(
    sentiments
#     %>% distinct(lexicon)
#     %>% filter(lexicon == 'nrc') %>% distinct(sentiment)
#     %>% filter(lexicon == 'AFINN') %>% distinct(score) %>% arrange(score)
    %>% filter(lexicon=="bing") %>% distinct(sentiment) 
#     %>% filter(lexicon == "loughran") %>% distinct(sentiment)
)
# Out:
#   sentiment
# 1 negative
# 2 positive

# %% [markdown]
# * 분석대상 데이터의 word 에 sentiment 사전의 결과를 컬럼 추가합니다.

# %%
(
    a_dlg_word
    %>% inner_join(sentiments)
    %>% anti_join(stop_words)
    %>% inner_join(hero_list %>% arrange(desc(cnt)) %>% head(20))
    
    %>% filter(lexicon == "AFINN")
    %>% group_by(movie, hero)
    %>% summarise(sentiment_sum = sum(score))
    %>% arrange(desc(sentiment_sum))
    
    %>% filter(movie == 3)
    
    ################################
    ## visualiation
    ################################
    %>% ggplot()
    + geom_bar(aes(x=reorder(hero, -sentiment_sum), y=sentiment_sum), stat="identity")
)
# Out:
# Joining, by = "word"
# Joining, by = c("word", "lexicon")
# Joining, by = "hero"
# plot without title

# %% [markdown]
# * nrc sentiment dictionary를 사용하면 단어에 감정의 종류를 분여할 수 있습니다.

# %%
(
    a_dlg_word
    %>% inner_join(sentiments)
    %>% anti_join(stop_words)
    %>% inner_join(hero_list %>% arrange(desc(cnt)) %>% head(20))
    
    %>% filter(lexicon == "nrc")
    
    %>% group_by(movie, hero,sentiment, word)
    %>% summarise(id_cnt = n_distinct(id))
    
    %>% group_by(movie, sentiment, hero)
    %>% summarise(sentiment_word_sum = sum(id_cnt))

    %>% arrange(desc(sentiment_word_sum))
    %>% top_n(5)
    %>% filter(movie == 3)
    %>% filter(sentiment  == 'trust')
    
    ################################
    ## visualiation
    ################################
    
#     %>% ggplot()
#     + geom_bar(aes(x=reorder(hero, sentiment_word_sum), y=sentiment_word_sum), stat="identity")
#     + coord_flip()
#     + facet_wrap(~ sentiment, ncol=2)
# #     %>% head(10)
)
# Out:
# Joining, by = "word"
# Joining, by = c("word", "lexicon")
# Joining, by = "hero"
# Selecting by sentiment_word_sum
#   movie sentiment hero           sentiment_word_sum
# 1 3     trust     Thor           29
# 2 3     trust     Tony Stark     27
# 3 3     trust     Thanos         22
# 4 3     trust     Peter Quill    19
# 5 3     trust     Doctor Strange 13
# 6 3     trust     Peter Parker   13
